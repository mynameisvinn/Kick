# %%
import numpy as np
from Kick import kick_web

# %%
a = np.random.rand(4, 4)
b = np.random.rand(4, 4)

# %%
a.dot(b)
# Out:
# array([[0.42682496, 0.58144689, 0.61713894, 0.83903853],
#        [0.84961358, 0.60034149, 0.63418183, 1.34085406],
#        [0.39727277, 0.4601724 , 0.484364  , 0.64225357],
#        [1.05963321, 1.17543067, 1.25175947, 1.71461471]])

# %%
@kick_web
def matmul(a, b):
    return a.dot(b)
# Out:
# >> initialize

# %%
c = matmul(a, b)
# Out:
# /Users/vincenttang/Dropbox/Temp/Kick
# ---------------------------------------------------------------------------
# NoSectionError                            Traceback (most recent call last)
# <ipython-input-5-92185fe79242> in <module>
# ----> 1 c = matmul(a, b)
#
# ~/Dropbox/Temp/Kick/Kick/kick_web.py in modified_func(*args)
#      22
#      23         # step 3: send source code to remote server
# ---> 24         res = up(fname)  # server's endpoints are found in config properties file
#      25
#      26         # step 4: return result
#
# ~/Dropbox/Temp/Kick/Kick/client.py in up(fname)
#      21     """
#      22     # get endpoint from config file
# ---> 23     h = fetch('remote', 'ip')
#      24     print(h)
#      25     # hostname = "3.236.152.182"
#
# ~/Dropbox/Temp/Kick/Kick/utils.py in fetch(section, field)
#       6     parser = SafeConfigParser()
#       7     parser.read('/config.ini')
# ----> 8     return parser.get(section, field)
#
# ...

# %%
c
# Out:
# array([[1.2416106 , 0.55910762, 0.69703909, 0.70765646],
#        [2.4075267 , 1.13992253, 1.47486529, 1.05101594],
#        [2.25183152, 1.26711627, 1.35230986, 1.28470277],
#        [1.74106834, 0.97434373, 1.0974327 , 0.83844974]])
