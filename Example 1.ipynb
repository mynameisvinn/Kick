# %%
import numpy as np
from Kick import kick

# %%
def matmul(a, b):
    return a.dot(b)

# %%
a = np.array([[ 5, 1 ,3], [ 1, 1 ,1], [ 1, 2 ,1]])
b = np.array([1, 2, 3])

# %%
matmul(a, b)  # executed locally

# %%
@kick
def matmul_remote(a, b):
    return a.dot(b)

# %%
matmul_remote(a, b)
