# %%
import numpy as np
from Kick import kick_web

# %%
a = np.random.rand(4, 4)
b = np.random.rand(4, 4)

# %%
@kick_web
def matmul(a, b):
    return a.dot(b)
# Out:
# >> initialize

# %%
d = matmul(a, b)
