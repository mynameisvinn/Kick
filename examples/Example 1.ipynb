# %%
import numpy as np
from Kick import kick_web
import os

# %%
np.random.seed(0)
a = np.random.rand(4, 4)
b = np.random.rand(4, 4)

# %%
a.dot(b)
# Out:
# array([[1.06663143, 1.640166  , 0.98766808, 2.02697933],
#        [1.15777507, 1.51872078, 0.92638976, 1.97653976],
#        [0.76437037, 1.8347494 , 1.18024954, 2.2950919 ],
#        [0.97116083, 1.29425033, 0.90240525, 1.35122485]])

# %%
@kick_web
def matmul(x, y):
    return x.dot(y)
# Out:
# >> initialize

# %%
matmul(a, b)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-10-2741037c29ee> in <module>
# ----> 1 matmul(a, b)
#
# ~/anaconda3/lib/python3.7/site-packages/Kick-1.0-py3.7.egg/Kick/kick_web.py in modified_func(*args)
#      37
#      38         # step 3: send source code to remote server
# ---> 39         res = up(fname)  # server's endpoints are found in config properties file
#      40
#      41         # step 4: delete temp file
#
# ~/anaconda3/lib/python3.7/site-packages/Kick-1.0-py3.7.egg/Kick/client.py in up(fname)
#      27     # create socket and connect with server
#      28     s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# ---> 29     s.connect((h, p))
#      30
#      31     # send source to server
#
# ConnectionRefusedError: [Errno 61] Connection refused
