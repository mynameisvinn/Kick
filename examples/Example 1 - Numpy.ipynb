# %%
import numpy as np
from Kick import kick
import astropy

# %%
np.random.seed(3)
a = np.random.rand(4, 4)
b = np.random.rand(4, 4)

# %%
a.dot(b)
# Out:
# array([[0.57061425, 1.50398765, 1.04239005, 0.74776316],
#        [0.42434032, 1.4123367 , 0.86701717, 0.6784842 ],
#        [0.31972514, 0.78538868, 0.66251945, 0.4043114 ],
#        [0.69208518, 1.63677287, 1.07481219, 0.86053276]])

# %%
@kick("gpu")
def matmul(x, y):
    return x.dot(y)
# Out:
# >> execution on gpu

# %%
matmul(a, b)
# Out:
# >>>>>>>>>> gpu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2741037c29ee> in <module>
# ----> 1 matmul(a, b)
#
# ~/anaconda3/lib/python3.7/site-packages/Kick-1.0-py3.7.egg/Kick/kick.py in modified_func(*args)
#      30             # step 4: send requirements.txt and source code to remote server
#      31             print(">>>>>>>>>>", target)
# ---> 32             res = up(fname)  # server's endpoints are found in config properties file
#      33
#      34             # step 5: clean up by deleting temp and requirements.txt
#
# ~/anaconda3/lib/python3.7/site-packages/Kick-1.0-py3.7.egg/Kick/client.py in up(fname)
#      22     # create socket and connect with server
#      23     s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# ---> 24     s.connect((h, p))
#      25
#      26     # read requirements as bytes and send bytes to server
#
# ...
