# %% [markdown]
# # [example](https://blog.ruanbekker.com/blog/2018/04/23/using-paramiko-module-in-python-to-execute-remote-bash-commands/)

# %%
from kick import kick

# %%
import os

def neat():
    res = 0
    for i in range(3):
        res += i
    return res

# %%
@kick
def bar():
    return neat()
# Out:
# ['', 'from kick import kick', 'import os\n\ndef neat():\n    res = 0\n    for i in range(3):\n        res += i\n    return res', '@kick\ndef bar():\n    return neat()']

# %%
bar()
# Out:
# bar()
# b'3'
